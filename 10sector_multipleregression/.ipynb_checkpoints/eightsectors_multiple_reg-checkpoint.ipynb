# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
sector_csv = 'data/tensectors_final.csv'

sector_df = pd.read_csv(sector_csv)

# %%
#drop unnamed column and two statistically not-significant variables from previous model
sector_df = sector_df.drop(columns=['Unnamed: 0','Real Estate','Telecommunication Services'],axis=1)

# %%
sector_df
# Out:
#            Date  Consumer Staples  Information Technology  \
# 0      1/2/2019             93.34                  157.92
# 1      1/3/2019             92.86                  142.19
# 2      1/4/2019             93.44                  148.26
# 3      1/7/2019             94.54                  147.93
# 4      1/8/2019             95.20                  150.75
# ..          ...               ...                     ...
# 246  12/23/2019            119.03                  284.00
# 247  12/24/2019            119.51                  284.27
# 248  12/26/2019            119.52                  289.91
# 249  12/27/2019            119.59                  289.80
# 250  12/30/2019            119.40                  291.52
#
#      Ameriprise Financial  Consumer Discretionary  Utilities  Health Care  \
# 0                  107.96                 1539.13      88.77       114.88
# 1                  105.10                 1500.28      89.12       111.31
# 2                  110.73                 1575.39      89.79       114.66
# 3                  111.24                 1629.51      88.84       115.28
# 4                  111.94                 1656.58      90.14       116.34
# ..                    ...                     ...        ...          ...
# 246                167.28                 1793.00     121.39       131.15
# 247                167.72                 1789.21     121.62       131.11
# 248                167.68                 1868.77     121.88       131.14
# 249                166.71                 1869.80     122.96       131.52
# 250                166.07                 1846.89     123.05       131.30
#
#      Materials  Energy  Industrials      S&P
# 0        29.18   14.72        84.18  2510.03
# 1        28.45   14.62        80.00  2447.89
# 2        30.39   15.41        82.68  2531.94
# 3        30.62   15.62        83.23  2549.69
# 4        31.36   15.48        82.38  2574.41
# ..         ...     ...          ...      ...
# 246      21.54   13.56        89.44  3224.01
# 247      21.45   13.62        89.15  3223.38
# 248      21.66   13.69        89.26  3239.91
# 249      21.22   13.48        88.37  3240.02
# 250      21.03   13.42        87.96  3221.29
#
# [251 rows x 11 columns]

# %%
#sklearn output for intercept and coefficients - removed Real Estate & Telecommunication Services

X = sector_df[['Consumer Staples','Information Technology','Ameriprise Financial','Consumer Discretionary','Utilities','Health Care','Materials','Energy','Industrials']] #8 variables for multiple regression
y = sector_df['S&P']
 
# with sklearn fit the model with all of x dependent variables or features
regr = linear_model.LinearRegression()
regr.fit(X, y)

model = LinearRegression()
model.fit(X,y)
score = model.score(X,y)

print('Intercept: ', regr.intercept_)
print('Coefficients: ', regr.coef_)
print('R2 Score: ', score)
# Out:
# Intercept:  132.94495575237988
# Coefficients:  [2.06902485 2.14298454 1.58860461 0.20015558 4.97401549 2.74724801
#  2.4192318  9.56083731 5.21209339]
# R2 Score:  0.9914656149546439

# %%
# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    S&P   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     3111.
# Date:                Mon, 17 Aug 2020   Prob (F-statistic):          8.69e-244
# Time:                        20:25:45   Log-Likelihood:                -1014.9
# No. Observations:                 251   AIC:                             2050.
# Df Residuals:                     241   BIC:                             2085.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    132.9450     57.543      2.310      0.022      19.594     246.296
# Consumer Staples           2.0690      0.495      4.177      0.000       1.093       3.045
# Information Technology     2.1430      0.110     19.527      0.000       1.927       2.359
# Ameriprise Financial       1.5886      0.150     10.573      0.000       1.293       1.885
# Consumer Discretionary     0.2002      0.016     12.455      0.000       0.168       0.232
# Utilities                  4.9740      0.356     13.973      0.000       4.273       5.675
# Health Care                2.7472      0.347      7.918      0.000       2.064       3.431
# Materials                  2.4192      1.005      2.407      0.017       0.439       4.399
# Energy                     9.5608      1.450      6.594      0.000       6.705      12.417
# Industrials                5.2121      0.537      9.702      0.000       4.154       6.270
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   0.474
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.211
# Skew:                          -0.035   Prob(JB):                        0.900
# Kurtosis:                       3.124   Cond. No.                     1.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Create a prediction with sklearn for Aug 3, 2020

con_staples = 129.3
info_tech = 435.75
financial = 155.69
con_disc = 3111.89
utilities = 147.06
health = 152.84
materials = 13.68
energy = 5.52
industrials = 31.88


print ('Predicted S&P500: ', regr.predict([[con_staples, info_tech, financial, con_disc, utilities, health, materials, energy, industrials]]))
# Out:
# Predicted S&P500:  [3607.86794587]
